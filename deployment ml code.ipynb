# %%
import pickle
import streamlit as st
from streamlit_option_menu import option_menu

# %%
#Load saved model
cholera_model = pickle.load(open('/content/drive/MyDrive/cholera_model.sav', 'rb'))

# %%
import streamlit as st
from streamlit_option_menu import option_menu

# Function to predict case status based on user inputs
def predict_case(diarrhoea, vomiting, dehydration, abdominal_pain, headache, age):
    # Dummy prediction logic for demonstration
    # Replace this with your actual model's prediction logic
    if diarrhoea and vomiting and dehydration:
        return "Positive"
    return "Negative"

# Sidebar for navigation
with st.sidebar:
    selected = option_menu('Disease Prediction',
                            ['Cholera Prediction'],
                            icons=['biohazard'],
                            menu_icon='cast',
                            default_index=0)

# Main content based on selection
if selected == 'Cholera Prediction':
    st.title('Cholera Prediction Model')
    st.write('Please input the following details to predict the case status.')

    # User inputs
    diarrhoea = st.checkbox('Diarrhoea')
    vomiting = st.checkbox('Vomiting')
    dehydration = st.checkbox('Dehydration')
    abdominal_pain = st.checkbox('Abdominal Pain/Cramps')
    headache = st.checkbox('Headache')
    age = st.number_input('Age', min_value=0, max_value=120)

    # Button to predict case status
    if st.button('Predict Case Status'):
        case_status = predict_case(diarrhoea, vomiting, dehydration, abdominal_pain, headache, age)
        st.success(f'Case Status: {case_status}')
# Out:
# 2024-12-03 19:58:23.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-03 19:58:23.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
